# %% [markdown]
# # Ex2 - Filtering and Sorting Data

# %% [markdown]
# This time we are going to pull data directly from the internet.
#
# ### Step 1. Import the necessary libraries

# %%
using CSV
using Statistics
using DataFrames
using Dates
using Downloads

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/02_Filtering_%26_Sorting/Euro12/Euro_2012_stats_TEAM.csv).

# %% [markdown]
# ### Step 3. Assign it to a variable called euro12.

# %%
url = "https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/02_Filtering_%26_Sorting/Euro12/Euro_2012_stats_TEAM.csv"
file = Downloads.download(url)
euro12 = CSV.read(file, DataFrame);

# %% [markdown]
# ### Step 4. Select only the Goal column.

# %%
euro12[!, :Goals];

# %% [markdown]
# ### Step 5. How many team participated in the Euro2012?

# %%
first(euro12, 3)
# Out:
# 3×35 DataFrame
#  Row │ Team            Goals  Shots on target  Shots off target  Shooting Accu ⋯
#      │ String31        Int64  Int64            Int64             String7       ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ Croatia             4               13                12  51.9%         ⋯
#    2 │ Czech Republic      4               13                18  41.9%
#    3 │ Denmark             4               10                10  50.0%
#                                                               31 columns omitted

# %%
unique(euro12[!, :Team])
# Out:
# 16-element Vector{String31}:
#  "Croatia"
#  "Czech Republic"
#  "Denmark"
#  "England"
#  "France"
#  "Germany"
#  "Greece"
#  "Italy"
#  "Netherlands"
#  "Poland"
#  "Portugal"
#  "Republic of Ireland"
#  "Russia"
#  "Spain"
#  "Sweden"
#  "Ukraine"

# %% [markdown]
# ### Step 6. What is the number of columns in the dataset?

# %%
length(names(euro12))
# Out:
# 35

# %% [markdown]
# ### Step 7. View only the columns Team, Yellow Cards and Red Cards and assign them to a dataframe called discipline

# %%
discipline = euro12[!, ["Team", "Yellow Cards", "Red Cards"]];

# %% [markdown]
# ### Step 8. Sort the teams by Red Cards, then to Yellow Cards

# %%
sort(discipline, ["Red Cards", "Yellow Cards"])
# Out:
# 16×3 DataFrame
#  Row │ Team                 Yellow Cards  Red Cards
#      │ String31             Int64         Int64
# ─────┼──────────────────────────────────────────────
#    1 │ Denmark                         4          0
#    2 │ Germany                         4          0
#    3 │ England                         5          0
#    4 │ Netherlands                     5          0
#    5 │ Ukraine                         5          0
#    6 │ France                          6          0
#    7 │ Russia                          6          0
#    8 │ Czech Republic                  7          0
#    9 │ Sweden                          7          0
#   10 │ Croatia                         9          0
#   11 │ Spain                          11          0
#   12 │ Portugal                       12          0
#   13 │ Italy                          16          0
#   14 │ Republic of Ireland             6          1
#   15 │ Poland                          7          1
#   16 │ Greece                          9          1

# %% [markdown]
# ### Step 9. Calculate the mean Yellow Cards given per Team

# %%
combine(
    groupby(
        euro12, "Team"
    ), "Yellow Cards" => mean
)
# Out:
# 16×2 DataFrame
#  Row │ Team                 Yellow Cards_mean
#      │ String31             Float64
# ─────┼────────────────────────────────────────
#    1 │ Croatia                            9.0
#    2 │ Czech Republic                     7.0
#    3 │ Denmark                            4.0
#    4 │ England                            5.0
#    5 │ France                             6.0
#    6 │ Germany                            4.0
#    7 │ Greece                             9.0
#    8 │ Italy                             16.0
#    9 │ Netherlands                        5.0
#   10 │ Poland                             7.0
#   11 │ Portugal                          12.0
#   12 │ Republic of Ireland                6.0
#   13 │ Russia                             6.0
#   14 │ Spain                             11.0
#   15 │ Sweden                             7.0
#   16 │ Ukraine                            5.0

# %% [markdown]
# ### Step 10. Filter teams that scored more than 6 goals

# %%
unique(euro12[euro12[!, :Goals] .> 6, :Team])
# Out:
# 2-element Vector{String31}:
#  "Germany"
#  "Spain"

# %% [markdown]
# ### Step 11. Select the teams that start with G

# %%
unique(euro12[first.(euro12[!, :Team], 1) .== "G", :Team])
# Out:
# 2-element Vector{String31}:
#  "Germany"
#  "Greece"

# %% [markdown]
# ### Step 12. Select the first 7 columns

# %%
names(euro12)[1:7]
# Out:
# 7-element Vector{String}:
#  "Team"
#  "Goals"
#  "Shots on target"
#  "Shots off target"
#  "Shooting Accuracy"
#  "% Goals-to-shots"
#  "Total shots (inc. Blocked)"

# %% [markdown]
# ### Step 13. Select all columns except the last 3.

# %%
names(euro12)[1:end-3]
# Out:
# 32-element Vector{String}:
#  "Team"
#  "Goals"
#  "Shots on target"
#  "Shots off target"
#  "Shooting Accuracy"
#  "% Goals-to-shots"
#  "Total shots (inc. Blocked)"
#  "Hit Woodwork"
#  "Penalty goals"
#  "Penalties not scored"
#  ⋮
#  "Blocks"
#  "Goals conceded"
#  "Saves made"
#  "Saves-to-shots ratio"
#  "Fouls Won"
#  "Fouls Conceded"
#  "Offsides"
#  "Yellow Cards"
#  "Red Cards"

# %% [markdown]
# ### Step 14. Present only the Shooting Accuracy from England, Italy and Russia

# %%
euro12[in.(euro12.Team, Ref(Set(["England", "Italy", "Russia"]))), ["Team","Shooting Accuracy"]]
# Out:
# 3×2 DataFrame
#  Row │ Team      Shooting Accuracy
#      │ String31  String7
# ─────┼─────────────────────────────
#    1 │ England   50.0%
#    2 │ Italy     43.0%
#    3 │ Russia    22.5%
