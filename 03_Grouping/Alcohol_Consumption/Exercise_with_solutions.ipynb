# %% [markdown]
# # Ex - GroupBy

# %% [markdown]
# ### Introduction:
#
# GroupBy can be summarized as Split-Apply-Combine.
#
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# Check out this [Diagram](http://i.imgur.com/yjNkiwL.png)
# ### Step 1. Import the necessary libraries

# %%
using DataFrames
using CSV
using Downloads
using Statistics

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/drinks.csv).

# %% [markdown]
# ### Step 3. Assign it to a variable called drinks.

# %%
file = Downloads.download("https://raw.githubusercontent.com/justmarkham/DAT8/master/data/drinks.csv")
drinks = CSV.read(file, DataFrame)
first(drinks, 3)
# Out:
# 3×6 DataFrame
#  Row │ country      beer_servings  spirit_servings  wine_servings  total_litre ⋯
#      │ String31     Int64          Int64            Int64          Float64     ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ Afghanistan              0                0              0              ⋯
#    2 │ Albania                 89              132             54
#    3 │ Algeria                 25                0             14
#                                                                2 columns omitted

# %% [markdown]
# ### Step 4. Which continent drinks more beer on average?

# %%
sort(combine(
    groupby(
        drinks, "continent"
    ), "beer_servings" => mean
), :beer_servings_mean, rev=true)
# Out:
# 6×2 DataFrame
#  Row │ continent  beer_servings_mean
#      │ String3    Float64
# ─────┼───────────────────────────────
#    1 │ EU                   193.778
#    2 │ SA                   175.083
#    3 │ NA                   145.435
#    4 │ OC                    89.6875
#    5 │ AF                    61.4717
#    6 │ AS                    37.0455

# %% [markdown]
# ### Step 5. For each continent print the statistics for wine consumption.

# %%
continent_gb = combine(
    groupby(drinks, :continent),
    :wine_servings => mean,
    :wine_servings => std,
    :wine_servings => maximum,
    :wine_servings => minimum,)
# Out:
# 6×5 DataFrame
#  Row │ continent  wine_servings_mean  wine_servings_std  wine_servings_maximum ⋯
#      │ String3    Float64             Float64            Int64                 ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ AS                    9.06818            21.667                     123 ⋯
#    2 │ EU                  142.222              97.4217                    370
#    3 │ AF                   16.2642             38.8464                    233
#    4 │ NA                   24.5217             28.2664                    100
#    5 │ SA                   62.4167             88.6202                    221 ⋯
#    6 │ OC                   35.625              64.5558                    212
#                                                                 1 column omitted

# %% [markdown]
# ### Step 6. Print the mean alcohol consumption per continent for every column

# %%
combine(
    groupby(
        drinks, :continent
    ), :total_litres_of_pure_alcohol => mean
)
# Out:
# 6×2 DataFrame
#  Row │ continent  total_litres_of_pure_alcohol_mean
#      │ String3    Float64
# ─────┼──────────────────────────────────────────────
#    1 │ AS                                   2.17045
#    2 │ EU                                   8.61778
#    3 │ AF                                   3.00755
#    4 │ NA                                   5.99565
#    5 │ SA                                   6.30833
#    6 │ OC                                   3.38125

# %% [markdown]
# ### Step 7. Print the median alcohol consumption per continent for every column

# %%
combine(
    groupby(
        drinks, :continent
    ), :total_litres_of_pure_alcohol => median
)
# Out:
# 6×2 DataFrame
#  Row │ continent  total_litres_of_pure_alcohol_median
#      │ String3    Float64
# ─────┼────────────────────────────────────────────────
#    1 │ AS                                        1.2
#    2 │ EU                                       10.0
#    3 │ AF                                        2.3
#    4 │ NA                                        6.3
#    5 │ SA                                        6.85
#    6 │ OC                                        1.75

# %% [markdown]
# ### Step 8. Print the mean, min and max values for spirit consumption.
# #### This time output a DataFrame

# %%
combine(
    groupby(
        drinks, :continent
    ), 
    :spirit_servings => mean,
    :spirit_servings => minimum,
    :spirit_servings => maximum
)
# Out:
# 6×4 DataFrame
#  Row │ continent  spirit_servings_mean  spirit_servings_minimum  spirit_servin ⋯
#      │ String3    Float64               Int64                    Int64         ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ AS                      60.8409                        0                ⋯
#    2 │ EU                     132.556                         0
#    3 │ AF                      16.3396                        0
#    4 │ NA                     165.739                        68
#    5 │ SA                     114.75                         25                ⋯
#    6 │ OC                      58.4375                        0
#                                                                 1 column omitted
